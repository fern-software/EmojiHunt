# %% [markdown]
# # Visualising Scores
# This notebook provides visualisations model scores for presentations in reports / presentations.

# %%
# These scores were taken from an official test run of the ml_method
scores = [1.4120226591665965, 1.4120226591665965, 2.140246567713527, 131.82035724867177, 3.2632659486293125, 90.14172325937172, 55.56106030220599, 4.522290923008127, 3.473547888231736, 1.8834271799576283, 2.164213562373095, 2.9350830028147548, 54.392954667948025, 1.553663105724556, 1.8251407699364424, 1.7772699034745352, 2.872975198209166, 129.05901699437496, 5.385164807134504, 1.4142135623730951, 2.4546614617227425, 2.1211390059588617, 3.859978678112602, 54.40016986350285, 1.595741732923815, 158.33367027408917, 1.2704174609988814, 3.3492268543381747, 2.3333333333333335, 3.1157101849785374, 2.8197401005057143, 1.7909472938922228, 2.1675115944274923, 60.6261646082715, 4.061208747436233, 2.8761265717752273, 180.61318478982562, 2.424899212039784, 1.949244862985006, 3.3950970339184083, 1.5107491837076632, 1.9846317877859057, 6.704223508755685, 1.8376962102505112, 1.612899020449196, 106.62887610615601, 1.495741732923815, 2.895954868683764, 1.0, 132.58698193755544]
final_score = 25.056511764635808

# %%
max_score = max(scores)
min_score = min(scores)
print(f'Max score: {max_score}, Min score: {min_score}')
# Out:
# Max score: 180.61318478982562, Min score: 1.0

# %%
import numpy as np
import matplotlib.pyplot as plt

# We want bins of 5 for our histogram
bins = np.arange(0, max_score, 5)

# Plot
_, ax = plt.subplots()
ax.hist(scores, bins=bins)
ax.set_title('Scores for official test run')
ax.set_xlabel('Score (binned)')
ax.set_ylabel('Frequency')

# Add an annotation for the final score
ax.annotate(f'Final score: {final_score:.2f}', xy=(final_score, 0), xytext=(final_score, 5), arrowprops=dict(facecolor='black', shrink=0.05))

plt.show()
